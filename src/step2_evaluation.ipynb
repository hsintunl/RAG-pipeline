# %%
import os
import pandas as pd
import numpy as np
import json
from datasets import Dataset
from tqdm import tqdm
import ast

import evaluate as hf_evaluate
from langchain_openai import ChatOpenAI
from langchain_community.embeddings import HuggingFaceEmbeddings
from ragas import evaluate
from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_recall

# %%
GENERATION_FILE_PATH = "/Users/connie/Desktop/Fall 2025/LLM/Assignment2/data/evaluation/all_experiment_generations.csv"
RESULTS_DIR = os.path.join("..", "results")
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
print("Reading generated data from:", GENERATION_FILE_PATH)
if not os.path.exists(GENERATION_FILE_PATH):
    raise FileNotFoundError("ERROR: Generation file not found. Please run naive_rag.py first.")

qa_df = pd.read_csv(GENERATION_FILE_PATH)
qa_df["answer"] = qa_df["answer"].astype(str)
# Out:
# Reading generated data from: /Users/connie/Desktop/Fall 2025/LLM/Assignment2/data/evaluation/all_experiment_generations.csv

# %%
qa_df.columns
# Out:
# Index(['question', 'answer', 'q_len', 'q_bin', 'gen_naive_k1_all-MiniLM-L6-v2',
#        'gen_cot_k1_all-MiniLM-L6-v2', 'gen_persona_k1_all-MiniLM-L6-v2',
#        'gen_naive_k3_all-MiniLM-L6-v2', 'gen_cot_k3_all-MiniLM-L6-v2',
#        'gen_persona_k3_all-MiniLM-L6-v2', 'gen_naive_k5_all-MiniLM-L6-v2',
#        'gen_cot_k5_all-MiniLM-L6-v2', 'gen_persona_k5_all-MiniLM-L6-v2',
#        'gen_naive_k1_all-mpnet-base-v2', 'gen_cot_k1_all-mpnet-base-v2',
#        'gen_persona_k1_all-mpnet-base-v2', 'gen_naive_k3_all-mpnet-base-v2',
#        'gen_cot_k3_all-mpnet-base-v2', 'gen_persona_k3_all-mpnet-base-v2',
#        'gen_naive_k5_all-mpnet-base-v2', 'gen_cot_k5_all-mpnet-base-v2',
#        'gen_persona_k5_all-mpnet-base-v2', 'contexts'],
#       dtype='object')

# %%
# Define embeddings model (used by RAGAS)
hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %% [markdown]
# ### Finding out the Basic QA Metrics (F1 score, EM score)

# %%
print("\n--- Running Basic QA Metrics (F1/EM) ---")

# Get columns to be evaluated (e.g., generated_naive_k1, generated_cot_k1)
generation_cols = [c for c in qa_df.columns if c.startswith('gen_')]
final_metrics_summary = []

for col in tqdm(generation_cols, desc="Calculating F1/EM"):
    
    # Extract strategy name (e.g., 'naive') and K value (e.g., 1) from column name
    parts = col.split('_')
    k_part = parts[-2] 
    retrieval_k = int(k_part.replace('k', ''))
    strategy_name = parts[1]
    embedding_dim = parts[-1] 
    
    metric_f1 = hf_evaluate.load("squad") 
    f1_scores, em_scores = [], []
    
    for pred_full, truth in zip(qa_df[col], qa_df["answer"]):
        
        # 1. Answer Extraction (Process CoT output format)
        pred = pred_full
        if strategy_name == "cot" and isinstance(pred_full, str) and "Final Answer:" in pred_full:
              # Extract text after the CoT marker
              pred = pred_full.split("Final Answer:")[1].strip()
        
        # 2. Calculate F1 and EM score
        result = metric_f1.compute(
            predictions=[{"prediction_text": str(pred), "id": "0"}],
            references=[{"answers": {"text": [str(truth)], "answer_start": [0]}, "id": "0"}]
        )
        f1_scores.append(result["f1"])
        em_scores.append(result["exact_match"])
        
    avg_f1, avg_em = np.mean(f1_scores), np.mean(em_scores)

    # Temporarily store F1/EM results
    final_metrics_summary.append({
        "Retrieval_K": retrieval_k,
        "Prompt_Strategy": strategy_name,
        "Embedding_Dim": embedding_dim,
        "Avg_F1": avg_f1,
        "Avg_EM": avg_em,
    })
# Out:
# --- Running Basic QA Metrics (F1/EM) ---
# Calculating F1/EM: 100%|████████████████████████| 18/18 [00:16<00:00,  1.06it/s]

# %%
# Convert results into DataFrame
results_df = pd.DataFrame(final_metrics_summary)

# Save to CSV
csv_path = os.path.join(RESULTS_DIR, "evaluation_f1_em.csv")
results_df.to_csv(csv_path, index=False)

# Pretty print top results (sorted by F1)
print("\n=== Evaluation Results (Top 10 by F1) ===")
print(results_df.sort_values(by="Avg_F1", ascending=False).head(10).to_string(index=False))

print(f"\n✅ Results saved to {csv_path}")
# Out:
# === Evaluation Results (Top 10 by F1) ===
#  Retrieval_K Prompt_Strategy     Embedding_Dim    Avg_F1    Avg_EM
#            5         persona all-mpnet-base-v2 49.857943 40.000000
#            5         persona  all-MiniLM-L6-v2 49.002727 39.166667
#            3         persona  all-MiniLM-L6-v2 46.555274 37.500000
#            3         persona all-mpnet-base-v2 44.691283 35.833333
#            5           naive all-mpnet-base-v2 41.772417 32.500000
#            5           naive  all-MiniLM-L6-v2 40.442060 30.833333
#            5             cot  all-MiniLM-L6-v2 38.771223 25.000000
#            5             cot all-mpnet-base-v2 38.412203 26.666667
#            1         persona  all-MiniLM-L6-v2 38.208599 30.833333
#            3             cot  all-MiniLM-L6-v2 37.215111 25.833333
#
# ✅ Results saved to ../results/evaluation_f1_em.csv

# %% [markdown]
# ### Advanced Evaluation using RAGAs

# %%
from dotenv import load_dotenv
load_dotenv()

llm_openai = ChatOpenAI(
    model="gpt-4o-mini",
    max_retries=5, # Increase retries to handle rate limits gracefully
)
hf_llm = llm_openai

# %%
# Parse contexts into clean lists of passage strings
def parse_context(ctx_str):
    try:
        ctx_obj = ast.literal_eval(ctx_str)  # safely parse string
        if isinstance(ctx_obj, dict) and "passage" in ctx_obj:
            return [ctx_obj["passage"]]
        elif isinstance(ctx_obj, list):
            return [c["passage"] for c in ctx_obj if isinstance(c, dict) and "passage" in c]
    except Exception:
        return []
    return []

qa_df["contexts_clean"] = qa_df["contexts"].apply(parse_context)

# %%
# ----------------------------------------------------
# STEP 1: Stratified sampling (done ONCE for all columns)
# ----------------------------------------------------
qa_df["q_len"] = qa_df["question"].apply(lambda x: len(str(x).split()))

# Define bins (short, medium, long) using percentiles
bins = np.percentile(qa_df["q_len"], [33, 66])
qa_df["q_bin"] = pd.cut(
    qa_df["q_len"],
    bins=[-1, bins[0], bins[1], float("inf")],
    labels=["short", "medium", "long"]
)

# Sample 40 from each bin (same random_state → deterministic)
subset_df = qa_df.groupby("q_bin", group_keys=False).apply(
    lambda x: x.sample(min(40, len(x)), random_state=42)
).reset_index(drop=True)

print(f"\n--- Using {len(subset_df)} stratified queries for ALL columns ---")
print(subset_df["q_bin"].value_counts())

# ----------------------------------------------------
# STEP 2: Run RAGAS per column, but on same 120 queries
# ----------------------------------------------------
chunk_size = 10  # row-level logging still works

for i, summary_data in enumerate(tqdm(final_metrics_summary, desc="Running RAGAS")):
    col = generation_cols[i]
    print(f"\nEvaluating column: {col}")

    metric_sums = {"faithfulness": 0, "answer_relevancy": 0,
                   "context_precision": 0, "context_recall": 0}
    total_rows = 0

    for start in range(0, len(subset_df), chunk_size):
        end = min(start + chunk_size, len(subset_df))
        print(f"{datetime.now().strftime('%H:%M:%S')} | Processing rows {start}–{end}...")

        for idx in range(start, end):
            row_data = Dataset.from_dict({
                "question": [str(subset_df["question"].iloc[idx])],
                "answer": [str(subset_df[col].iloc[idx])],
                "contexts": [subset_df["contexts_clean"].iloc[idx]],
                "ground_truths": [[str(subset_df["answer"].iloc[idx])]],
                "reference": [str(subset_df["answer"].iloc[idx])],
            })

            try:
                res = evaluate(
                    row_data,
                    metrics=[faithfulness, answer_relevancy,
                             context_precision, context_recall],
                    llm=hf_llm,
                    embeddings=hf_embeddings,
                    show_progress=False,
                    batch_size=1
                )

                for k in metric_sums.keys():
                    val = res[k]
                    if isinstance(val, list):  # ragas sometimes returns [score]
                        val = val[0]
                    metric_sums[k] += val
                total_rows += 1

                print(f"   Done row {idx+1}/{len(subset_df)} | {res}")

            except Exception as e:
                print(f"   Row {idx+1} failed: {e}")

    if total_rows > 0:
        for k in metric_sums.keys():
            metric_sums[k] /= total_rows
        summary_data.update({
            "Embedding_Dim": final_metrics_summary[i]['Embedding_Dim'],
            "Ragas_Faithfulness": metric_sums["faithfulness"],
            "Ragas_Answer_Relevancy": metric_sums["answer_relevancy"],
            "Ragas_Context_Precision": metric_sums["context_precision"],
            "Ragas_Context_Recall": metric_sums["context_recall"]
        })
        print(f"{datetime.now().strftime('%H:%M:%S')} | Completed {col} with averages: {metric_sums}")
    else:
        print(f"{datetime.now().strftime('%H:%M:%S')} | No valid rows processed for {col}")
        summary_data.update({
            "Ragas_Faithfulness": None,
            "Ragas_Answer_Relevancy": None,
            "Ragas_Context_Precision": None,
            "Ragas_Context_Recall": None
        })
# Out:
# /var/folders/k3/vcbwsjp93rl2cww52jf518fc0000gn/T/ipykernel_15058/1150768349.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   subset_df = qa_df.groupby("q_bin", group_keys=False).apply(
# /var/folders/k3/vcbwsjp93rl2cww52jf518fc0000gn/T/ipykernel_15058/1150768349.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   subset_df = qa_df.groupby("q_bin", group_keys=False).apply(
# --- Using 120 stratified queries for ALL columns ---
# q_bin
# short     40
# medium    40
# long      40
# Name: count, dtype: int64
# Running RAGAS:   0%|                                     | 0/18 [00:00<?, ?it/s]
# Evaluating column: gen_naive_k1_all-MiniLM-L6-v2
# 00:45:13 | Processing rows 0–10...
#    Done row 1/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1109, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 2/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0638, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 3/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1015, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 4/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0827, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 5/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0778, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 6/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0655, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 7/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0310, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 8/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0825, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 9/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0695, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 10/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0267, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 00:50:31 | Processing rows 10–20...
#    Done row 11/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1390, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 12/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0494, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 13/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0495, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 14/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.1320, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 15/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1040, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 16/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1043, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 17/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0830, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 18/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0045, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 19/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0872, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 20/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0092, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 00:57:33 | Processing rows 20–30...
#    Done row 21/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0284, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 22/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0277, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 23/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1146, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 24/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2271, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 25/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1247, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 26/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0644, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 27/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0754, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 28/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0395, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 29/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0416, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 30/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0573, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:05:05 | Processing rows 30–40...
#    Done row 31/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1494, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 32/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0948, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 33/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0217, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 34/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1238, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 35/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0207, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 36/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0145, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 37/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0062, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 38/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1392, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 39/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0076, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 40/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1463, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:12:08 | Processing rows 40–50...
#    Done row 41/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0854, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 42/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0148, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 43/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0345, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 44/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0804, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 45/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0073, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 46/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0843, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 47/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0744, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 48/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0544, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 49/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0050, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 50/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0846, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:19:11 | Processing rows 50–60...
#    Done row 51/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0193, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 52/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0501, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 53/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0999, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 54/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0760, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 55/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0406, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 56/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0183, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 57/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0629, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 58/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0137, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 59/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0899, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 60/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0983, 'context_precision': 1.0000, 'context_recall': 0.0000}
# 01:26:31 | Processing rows 60–70...
#    Done row 61/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0458, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 62/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0192, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 63/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0835, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 64/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0147, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 65/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1145, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 66/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0202, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 67/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.0927, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 68/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0583, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 69/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0015, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 70/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0993, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:33:42 | Processing rows 70–80...
#    Done row 71/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0405, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 72/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0460, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 73/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0593, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 74/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0632, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 75/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0716, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 76/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0330, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 77/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0472, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 78/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0457, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 79/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0547, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 80/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1382, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:40:50 | Processing rows 80–90...
#    Done row 81/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0138, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 82/120 | {'faithfulness': 1.0000, 'answer_relevancy': -0.0231, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 83/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0508, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 84/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0250, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 85/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0005, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 86/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0148, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 87/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0791, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 88/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1380, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 89/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0197, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 90/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0310, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:48:08 | Processing rows 90–100...
#    Done row 91/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0020, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 92/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0562, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 93/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0885, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 94/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0235, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 95/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.1159, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 96/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0806, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 97/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1211, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 98/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0888, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 99/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0998, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 100/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1773, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:55:09 | Processing rows 100–110...
#    Done row 101/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0993, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 102/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0089, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 103/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0325, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 104/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0450, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 105/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1634, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 106/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0993, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 107/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0497, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 108/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1212, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 109/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0990, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 110/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0559, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 02:02:26 | Processing rows 110–120...
#    Done row 111/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0269, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 112/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0363, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 113/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1265, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 114/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0513, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 115/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0122, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 116/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0525, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 117/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0804, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 118/120 | {'faithfulness': 0.0000, 'answer_relevancy': -0.0262, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 119/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1110, 'context_precision': 1.0000, 'context_recall': 1.0000}
# Running RAGAS:   6%|█▏                    | 1/18 [1:24:29<23:56:20, 5069.45s/it]
#    Done row 120/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0567, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:09:42 | Completed gen_naive_k1_all-MiniLM-L6-v2 with averages: {'faithfulness': 0.041666666666666664, 'answer_relevancy': 0.0573861232211372, 'context_precision': 0.724999999927499, 'context_recall': 0.6166666666666667}
#
# Evaluating column: gen_cot_k1_all-MiniLM-L6-v2
# 02:09:42 | Processing rows 0–10...
#    Done row 1/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7395, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 2/120 | {'faithfulness': 0.9091, 'answer_relevancy': 0.6597, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 3/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.5209, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 4/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2886, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 5/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.9580, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 6/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3271, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 7/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3476, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 8/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3502, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 9/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1197, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 10/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1794, 'context_precision': 0.0000, 'context_recall': 1.0000}
# 02:17:09 | Processing rows 10–20...
#    Done row 11/120 | {'faithfulness': 0.8571, 'answer_relevancy': 0.5850, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 12/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1686, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 13/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.8581, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 14/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1452, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 15/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7615, 'context_precision': 0.0000, 'context_recall': 1.0000}
#    Done row 16/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.6527, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 17/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2731, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 18/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4961, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 19/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.8411, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 20/120 | {'faithfulness': 0.8333, 'answer_relevancy': 0.5020, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 02:24:01 | Processing rows 20–30...
#    Done row 21/120 | {'faithfulness': 0.5000, 'answer_relevancy': 1.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 22/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3729, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 23/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1527, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 24/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7889, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 25/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0566, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 26/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3384, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 27/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6622, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 28/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2716, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 29/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.3132, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 30/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8076, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:31:18 | Processing rows 30–40...
#    Done row 31/120 | {'faithfulness': 0.8000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 32/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6236, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 33/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 34/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2473, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 35/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.8255, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 36/120 | {'faithfulness': 0.8000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 37/120 | {'faithfulness': 0.6667, 'answer_relevancy': 1.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 38/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4536, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 39/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6819, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 40/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:38:28 | Processing rows 40–50...
#    Done row 41/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3436, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 42/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 43/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2650, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 44/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.1305, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 45/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1967, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 46/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 47/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1866, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 48/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.8343, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 49/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.9365, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 50/120 | {'faithfulness': 0.8889, 'answer_relevancy': 0.5531, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:45:42 | Processing rows 50–60...
#    Done row 51/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1513, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 52/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 53/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.8086, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 54/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7853, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 55/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 56/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1997, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 57/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5080, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 58/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.8794, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 59/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6888, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 60/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.6037, 'context_precision': 1.0000, 'context_recall': 0.0000}
# 02:52:52 | Processing rows 60–70...
#    Done row 61/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2726, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 62/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.9821, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 63/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1912, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 64/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 65/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 66/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.1004, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 67/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.5823, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 68/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7198, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 69/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8172, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 70/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4400, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:00:02 | Processing rows 70–80...
#    Done row 71/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 72/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3639, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 73/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.4660, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 74/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6046, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 75/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3357, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 76/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.8650, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 77/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7687, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 78/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 79/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5609, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 80/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1766, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:07:14 | Processing rows 80–90...
#    Done row 81/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.4482, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 82/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8730, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 83/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.6915, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 84/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1025, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 85/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.8115, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 86/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 87/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3445, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 88/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.4622, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 89/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7648, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 90/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.9153, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:14:28 | Processing rows 90–100...
#    Done row 91/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6137, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 92/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 93/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6442, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 94/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.9713, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 95/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.3895, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 96/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.9258, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 97/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.7123, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 98/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3265, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 99/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1978, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 100/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.9258, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:21:44 | Processing rows 100–110...
#    Done row 101/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.6133, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 102/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8466, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 103/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3381, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 104/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3992, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 105/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.2212, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 106/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.3940, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 107/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.6958, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 108/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0971, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 109/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.6026, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 110/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6145, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 03:28:54 | Processing rows 110–120...
#    Done row 111/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 112/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.8164, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 113/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2507, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 114/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8010, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 115/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.0856, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 116/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9305, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 117/120 | {'faithfulness': 0.8000, 'answer_relevancy': 0.8758, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 118/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.7385, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 119/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8354, 'context_precision': 1.0000, 'context_recall': 1.0000}
# Running RAGAS:  11%|██▍                   | 2/18 [2:50:52<22:49:38, 5136.13s/it]
#    Done row 120/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:36:05 | Completed gen_cot_k1_all-MiniLM-L6-v2 with averages: {'faithfulness': 0.6324037999037999, 'answer_relevancy': 0.46637369879760854, 'context_precision': 0.7083333332624989, 'context_recall': 0.625}
#
# Evaluating column: gen_persona_k1_all-MiniLM-L6-v2
# 03:36:05 | Processing rows 0–10...
#    Done row 1/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0710, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 2/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8618, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 3/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.5207, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 4/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4170, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 5/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8561, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 6/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3393, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 7/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3427, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 8/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3502, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 9/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1528, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 10/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1794, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:43:28 | Processing rows 10–20...
#    Done row 11/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1074, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 12/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1133, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 13/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1973, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 14/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1452, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 15/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7615, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 16/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 17/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2428, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 18/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4961, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 19/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1009, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 20/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3931, 'context_precision': 1.0000, 'context_recall': 0.0000}
# 03:50:26 | Processing rows 20–30...
#    Done row 21/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1681, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 22/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3729, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 23/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1316, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 24/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 25/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 26/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4555, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 27/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3551, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 28/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2672, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 29/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2527, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 30/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.8076, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 03:57:38 | Processing rows 30–40...
#    Done row 31/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 32/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3224, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 33/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 34/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2098, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 35/120 | {'faithfulness': 0.6667, 'answer_relevancy': 0.9269, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 36/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.7047, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 37/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9464, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 38/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3253, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 39/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6904, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 40/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:04:49 | Processing rows 40–50...
#    Done row 41/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3363, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 42/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1826, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 43/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5332, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 44/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 45/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1991, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 46/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.5106, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 47/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2354, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 48/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1656, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 49/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.9365, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 50/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1556, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:11:52 | Processing rows 50–60...
#    Done row 51/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1513, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 52/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4275, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 53/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 54/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7136, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 55/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8298, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 56/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1567, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 57/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6481, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 58/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1675, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 59/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6888, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 60/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9252, 'context_precision': 1.0000, 'context_recall': 0.0000}
# 04:19:16 | Processing rows 60–70...
#    Done row 61/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3376, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 62/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9255, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 63/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1162, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 64/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2116, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 65/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4070, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 66/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0898, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 67/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.5823, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 68/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7159, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 69/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.7202, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 70/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4272, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:26:26 | Processing rows 70–80...
#    Done row 71/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 72/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3639, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 73/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.5136, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 74/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6105, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 75/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3357, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 76/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1368, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 77/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9673, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 78/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 79/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5577, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 80/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1717, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:33:17 | Processing rows 80–90...
#    Done row 81/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0988, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 82/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8730, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 83/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0957, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 84/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1604, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 85/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0795, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 86/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4461, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 87/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3071, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 88/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4251, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 89/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7503, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 90/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9153, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:40:45 | Processing rows 90–100...
#    Done row 91/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5743, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 92/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2778, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 93/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0910, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 94/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8406, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 95/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3631, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 96/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9258, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 97/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7123, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 98/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3442, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 99/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 100/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8647, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 04:48:06 | Processing rows 100–110...
#    Done row 101/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4295, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 102/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8466, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 103/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3009, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 104/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4979, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 105/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.2280, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 106/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4217, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 107/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1263, 'context_precision': 0.0000, 'context_recall': 0.0000}
# ...
#    Done row 3/120 | {'faithfulness': 0.2500, 'answer_relevancy': 0.7570, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 4/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2225, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 5/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8983, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 6/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3271, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 7/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3514, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 8/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2913, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 9/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1249, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 10/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1627, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:19:09 | Processing rows 10–20...
#    Done row 11/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1218, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 12/120 | {'faithfulness': 1.0000, 'answer_relevancy': -0.0107, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 13/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.8309, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 14/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1452, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 15/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7615, 'context_precision': 0.0000, 'context_recall': 1.0000}
#    Done row 16/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 17/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2731, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 18/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4961, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 19/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1033, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 20/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3931, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 01:26:12 | Processing rows 20–30...
#    Done row 21/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7803, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 22/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1406, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 23/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0930, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 24/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 25/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7459, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 26/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2587, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 27/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6242, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 28/120 | {'faithfulness': 1.0000, 'answer_relevancy': -0.0022, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 29/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0550, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 30/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8076, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:33:12 | Processing rows 30–40...
#    Done row 31/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6698, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 32/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2496, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 33/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 34/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2454, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 35/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 36/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0668, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 37/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9602, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 38/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3253, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 39/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6862, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 40/120 | {'faithfulness': 0.7500, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:39:27 | Processing rows 40–50...
#    Done row 41/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3473, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 42/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.5576, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 43/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 44/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 45/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0283, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 46/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.5106, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 47/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1459, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 48/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7660, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 49/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9365, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 50/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1555, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 01:47:32 | Processing rows 50–60...
#    Done row 51/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1513, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 52/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4275, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 53/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2554, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 54/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7136, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 55/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.9308, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 56/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2129, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 57/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5936, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 58/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1942, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 59/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6888, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 60/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9252, 'context_precision': 1.0000, 'context_recall': 0.0000}
# 01:54:58 | Processing rows 60–70...
#    Done row 61/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5079, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 62/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0830, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 63/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0281, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 64/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2181, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 65/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.6151, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 66/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0973, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 67/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5717, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 68/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7226, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 69/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1210, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 70/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4430, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:01:59 | Processing rows 70–80...
#    Done row 71/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 72/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1320, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 73/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.5150, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 74/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.5907, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 75/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2585, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 76/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1341, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 77/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9673, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 78/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0000, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 79/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.5577, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 80/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.1214, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:08:08 | Processing rows 80–90...
#    Done row 81/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0606, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 82/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8730, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 83/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1865, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 84/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1593, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 85/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0445, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 86/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0104, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 87/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.3372, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 88/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.8253, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 89/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7811, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 90/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9153, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:16:15 | Processing rows 90–100...
#    Done row 91/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2056, 'context_precision': 0.0000, 'context_recall': 1.0000}
#    Done row 92/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0323, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 93/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1034, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 94/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8406, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 95/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3631, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 96/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9258, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 97/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7123, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 98/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.2721, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 99/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.4110, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 100/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8700, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:22:21 | Processing rows 100–110...
#    Done row 101/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.7019, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 102/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8466, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 103/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.3381, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 104/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4896, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 105/120 | {'faithfulness': 0.5000, 'answer_relevancy': 0.2212, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 106/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.4090, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 107/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2041, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 108/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0971, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 109/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.6410, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 110/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.8006, 'context_precision': 0.0000, 'context_recall': 0.0000}
# 02:30:14 | Processing rows 110–120...
#    Done row 111/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.1731, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 112/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8164, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 113/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2507, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 114/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.2830, 'context_precision': 0.0000, 'context_recall': 0.0000}
#    Done row 115/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0585, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 116/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.9305, 'context_precision': 1.0000, 'context_recall': 1.0000}
#    Done row 117/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.0691, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 118/120 | {'faithfulness': 0.0000, 'answer_relevancy': 0.1028, 'context_precision': 1.0000, 'context_recall': 0.0000}
#    Done row 119/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.8354, 'context_precision': 1.0000, 'context_recall': 1.0000}
# Running RAGAS: 100%|███████████████████████| 18/18 [25:52:51<00:00, 5176.17s/it]
#    Done row 120/120 | {'faithfulness': 1.0000, 'answer_relevancy': 0.0000, 'context_precision': 1.0000, 'context_recall': 1.0000}
# 02:38:04 | Completed gen_persona_k5_all-mpnet-base-v2 with averages: {'faithfulness': 0.6125, 'answer_relevancy': 0.38534648149643247, 'context_precision': 0.716666666594999, 'context_recall': 0.625}

# %% [markdown]
# ### Final Results Storage

# %%
# Define results directory explicitly (one level up from src/)
RESULTS_DIR = os.path.join("..", "results")
os.makedirs(RESULTS_DIR, exist_ok=True)

# Save the sampled subset queries (for reproducibility and appendix)
subset_path = os.path.join(RESULTS_DIR, "subset_queries.csv")
subset_df.to_csv(subset_path, index=False)
print(f"\nSampled queries saved to {subset_path}")

# Convert evaluation results into DataFrame
results_df = pd.DataFrame(final_metrics_summary)

# Save results to CSV
csv_path = os.path.join(RESULTS_DIR, "comparison_analysis.csv")
results_df.to_csv(csv_path, index=False)

print("\nEvaluation Finalized.")
print(f"Metrics saved to {json_path} and {csv_path}")
# Out:
# Sampled queries saved to ../results/subset_queries.csv
#
# Evaluation Finalized.
# Metrics saved to ../results/naive_results.json and ../results/comparison_analysis.csv
